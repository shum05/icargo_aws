# %% [markdown]
# ## Cargo Screener Certification-Exam-Readiness Predictor

# %% [markdown]
# ### ML Project Life cycle
#
# 1. Understanding the Problem Statement
# 1. Data Collection
# 1. Data Checks -to ensure the quality and integrity of the data
# 1. EDA
# 1. Data Pre-Processing
#      1. Data Cleaning
#      1. Data Transformation
#      1. Feature Scaling
#      1. Data Splitting
#      1. Handling Text Data
#      1. Feature Scaling and Normalization
#      1. Data Standardization
#      1. Data Encoding and Labeling
#      1. Data Imputation
#      1. Data Balancing
#      1. Data Documentation and Logging
# 1. Model Training
# 1. Choose best model

# %% [markdown]
# ### Data Collection
# - Dataset Source - company data with modified column names and values
# - The data consists of 13 column and 1600 rows.

# %% [markdown]
# ### Import Data and Required Packages

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load raw data

# %%
df = pd.read_csv('data/cargo_screener.csv')

# %%
# show top 5 rows
df.head()
# Out:
#    gender race_ethnicity level_of_education language_proficiency  \
# 0    male        group A        high school               fluent
# 1  female        group E       some college         intermediate
# 2    male        group A       some college               fluent
# 3  female        group E       some college               fluent
# 4    male        group E       some college               fluent
#
#   training_manuals  hr_interview_score  x_ray_module_assessment_score  \
# 0             none                  63                             74
# 1         provided                  83                             95
# 2             none                  46                             58
# 3         provided                  71                             83
# 4             none                  68                             80
#
#    etd_module_assessment_score  phy_module_assessment_score  \
# 0                           63                         69.0
# 1                           83                         89.0
# 2                           46                         52.0
# 3                           71                         77.0
# 4                           68                         74.0
#
#    dg_module_assessment_score  tsa_test_score  cbp_test_score  \
# 0                          66              63            62.0
# 1                          89              88            85.0
# 2                          47              43            43.0
# 3                          76              74            73.0
# 4                          72              72            65.0
#
#    Certification_exam_score
# 0                      63.0
# 1                      75.0
# 2                      53.0
# 3                      66.0
# 4                      68.0

# %%
# show bottom 5 rows
df.tail()
# Out:
#       gender race_ethnicity  level_of_education language_proficiency  \
# 1595  female        group C        some college               fluent
# 1596  female        group A         high school         intermediate
# 1597    male        group A        some college         intermediate
# 1598    male        group C  associate's degree               fluent
# 1599  female        group A        some college               fluent
#
#      training_manuals  hr_interview_score  x_ray_module_assessment_score  \
# 1595             none                  63                             75
# 1596             none                  63                             76
# 1597         provided                  80                             92
# 1598             none                  40                             51
# 1599             none                  59                             71
#
#       etd_module_assessment_score  phy_module_assessment_score  \
# 1595                           63                         69.0
# 1596                           63                         69.0
# 1597                           80                         86.0
# 1598                           40                         46.0
# 1599                           59                         65.0
#
#       dg_module_assessment_score  tsa_test_score  cbp_test_score  \
# 1595                          69              69            65.0
# 1596                          71              67            73.0
# 1597                          83              78            81.0
# 1598                          41              37            35.0
# 1599                          64              58            64.0
#
#       Certification_exam_score
# 1595                      55.0
# 1596                      50.0
# 1597                      81.0
# 1598                      47.0
# 1599                      56.0

# %% [markdown]
# #### dataset shape and info

# %%
df.shape
# Out:
# (1600, 13)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>INSIGHTS </b>&#9658
# <ul>
#  <li>There are 303 rows and 14 columns in the dataset,
#           total of 13 features and 1 target variable</li>
#
#  </ul>
# </div>

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# 1. age : age of persons
# 1. gender : gender of trainee/examinee (3 values)
#
# 1. race_ethnicity : race of examinee (5 values)
#
# 1. level_of_education : EXAMINEE'S EDUCATIONAL LEVEL ( values)
# 1. language_proficiency : examinee's ability to communicate effectively in a English language
# 1. training_manuals : weather examinee has been covered all training manuals provided
#
# 1. hr_interview_score : result examinee scored in the test at the begining of recruitment
#
# 1. x_ray_module_assessment_score,etd_module_assessment_score,phy_module_assessment_score,dg_module_assessment_score : columns for result examinee scored in the tests for each of the modules at end of each module
# 1. tsa_test_score : result examinee scored in the tsa-prepared test
#
# 1. cbp_test_score : result examinee scored in the cbp-prepared test
# 1. Output--> Certification_exam_score : the final exam score for certification with examinee who scores less than 85% Failed

# %% [markdown]
# ###  Data Checks
#
# - Check Missing values
# - Check Duplicates
# - Check data type
# - Check the number of unique values of each column
# - Check statistics of data set
# - Check various categories present in the different categorical column

# %%
# check for missing values
df.isna().sum()
# Out:
# gender                            0
# race_ethnicity                    0
# level_of_education               10
# language_proficiency              0
# training_manuals                 12
# hr_interview_score                0
# x_ray_module_assessment_score     0
# etd_module_assessment_score       0
# phy_module_assessment_score       1
# dg_module_assessment_score        0
# tsa_test_score                    0
# cbp_test_score                    1
# Certification_exam_score          1
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>INSIGHTS </b>&#9658
# There are missing values in some columns

# %%
# check for duplicates
len(df[df.duplicated()])
# Out:
# 483

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>INSIGHTS </b>&#9658
# There are 483 duplicate values in the dataset

# %% [markdown]
# ### Handling Missing and Duplicate values

# %%
# Drop the duplicate data
df = df.drop_duplicates()

# %%
# check for  duplicate data
num_duplicates = len(df[df.duplicated(keep=False)])  # Use 'keep=False' to count all duplicates
print(f"Number of duplicate rows: {num_duplicates}")
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>INSIGHTS </b>&#9658
# There are no duplicate values in the dataset

# %%
# Imputation for missing values
# numerical columns

df['phy_module_assessment_score'].fillna(df['phy_module_assessment_score'].mean(), inplace=True)
df['cbp_test_score'].fillna(df['cbp_test_score'].mean(), inplace=True)
df['Certification_exam_score'].fillna(df['Certification_exam_score'].mean(), inplace=True)

# categorical columns
df['level_of_education'].fillna(df['level_of_education'].mode()[0], inplace=True)
df['training_manuals'].fillna(df['training_manuals'].mode()[0], inplace=True)

# %%
# check for missing data
df.isna().sum()
# Out:
# gender                           0
# race_ethnicity                   0
# level_of_education               0
# language_proficiency             0
# training_manuals                 0
# hr_interview_score               0
# x_ray_module_assessment_score    0
# etd_module_assessment_score      0
# phy_module_assessment_score      0
# dg_module_assessment_score       0
# tsa_test_score                   0
# cbp_test_score                   0
# Certification_exam_score         0
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>INSIGHTS </b>&#9658
# There are no missing values in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1117 entries, 0 to 1576
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   gender                         1117 non-null   object
#  1   race_ethnicity                 1117 non-null   object
#  2   level_of_education             1117 non-null   object
#  3   language_proficiency           1117 non-null   object
#  4   training_manuals               1117 non-null   object
#  5   hr_interview_score             1117 non-null   int64
#  6   x_ray_module_assessment_score  1117 non-null   int64
#  7   etd_module_assessment_score    1117 non-null   int64
#  8   phy_module_assessment_score    1117 non-null   float64
#  9   dg_module_assessment_score     1117 non-null   int64
#  10  tsa_test_score                 1117 non-null   int64
#  11  cbp_test_score                 1117 non-null   float64
#  12  Certification_exam_score       1117 non-null   float64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 122.2+ KB

# %%
df.shape
# Out:
# (1117, 13)

# %%
df.nunique()
# Out:
# gender                            3
# race_ethnicity                    5
# level_of_education                6
# language_proficiency              3
# training_manuals                  2
# hr_interview_score               74
# x_ray_module_assessment_score    76
# etd_module_assessment_score      75
# phy_module_assessment_score      74
# dg_module_assessment_score       74
# tsa_test_score                   72
# cbp_test_score                   78
# Certification_exam_score         82
# dtype: int64

# %%
df.describe().T
# Out:
#                                 count       mean        std   min   25%   50%  \
# hr_interview_score             1117.0  68.496867  14.532476   9.0  59.0  69.0
# x_ray_module_assessment_score  1117.0  79.916741  14.270532  21.0  70.0  81.0
# etd_module_assessment_score    1117.0  68.480752  14.614363   9.0  59.0  69.0
# phy_module_assessment_score    1117.0  74.462366  14.581418  15.0  65.0  75.0
# dg_module_assessment_score     1117.0  72.412713  14.807146  15.0  62.0  73.0
# tsa_test_score                 1117.0  69.894360  14.905483  17.0  60.0  71.0
# cbp_test_score                 1117.0  68.918459  15.506259  10.0  58.0  70.0
# Certification_exam_score       1117.0  66.687276  15.408065   0.0  57.0  67.0
#
#                                 75%    max
# hr_interview_score             79.0  101.0
# x_ray_module_assessment_score  90.0  112.0
# etd_module_assessment_score    79.0  103.0
# phy_module_assessment_score    85.0  106.0
# dg_module_assessment_score     83.0  103.0
# tsa_test_score                 81.0  100.0
# cbp_test_score                 80.0  100.0
# Certification_exam_score       77.0  100.0

# %% [markdown]
# ### more deeper data exporation

# %%
df.head()
# Out:
#    gender race_ethnicity level_of_education language_proficiency  \
# 0    male        group A        high school               fluent
# 1  female        group E       some college         intermediate
# 2    male        group A       some college               fluent
# 3  female        group E       some college               fluent
# 4    male        group E       some college               fluent
#
#   training_manuals  hr_interview_score  x_ray_module_assessment_score  \
# 0             none                  63                             74
# 1         provided                  83                             95
# 2             none                  46                             58
# 3         provided                  71                             83
# 4             none                  68                             80
#
#    etd_module_assessment_score  phy_module_assessment_score  \
# 0                           63                         69.0
# 1                           83                         89.0
# 2                           46                         52.0
# 3                           71                         77.0
# 4                           68                         74.0
#
#    dg_module_assessment_score  tsa_test_score  cbp_test_score  \
# 0                          66              63            62.0
# 1                          89              88            85.0
# 2                          47              43            43.0
# 3                          76              74            73.0
# 4                          72              72            65.0
#
#    Certification_exam_score
# 0                      63.0
# 1                      75.0
# 2                      53.0
# 3                      66.0
# 4                      68.0

# %%
# unique values in cat columns
print("Categories in 'gender' variable:     ",end=" " )
print(df['gender'].unique())

print("Categories in 'race_ethnicity' variable:  ",end=" ")
print(df['race_ethnicity'].unique())

print("Categories in'level of education' variable:",end=" " )
print(df['level_of_education'].unique())

print("Categories in 'language proficiency' variable:     ",end=" " )
print(df['language_proficiency'].unique())

print("Categories in 'training manuals' variable:     ",end=" " )
print(df['training_manuals'].unique())
# Out:
# Categories in 'gender' variable:      ['male' 'female' 'other']
# Categories in 'race_ethnicity' variable:   ['group A' 'group E' 'group B' 'group D' 'group C']
# Categories in'level of education' variable: ['high school' 'some college' 'some high school' "associate's degree"
#  "bachelor's degree" "master's degree"]
# Categories in 'language proficiency' variable:      ['fluent' 'intermediate' 'limitted']
# Categories in 'training manuals' variable:      ['none' 'provided']

# %%
# define numerical & categorical columns
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# print columns
print('There are {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nThere are {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# There are 8 numerical features : ['hr_interview_score', 'x_ray_module_assessment_score', 'etd_module_assessment_score', 'phy_module_assessment_score', 'dg_module_assessment_score', 'tsa_test_score', 'cbp_test_score', 'Certification_exam_score']
#
# There are 5 categorical features : ['gender', 'race_ethnicity', 'level_of_education', 'language_proficiency', 'training_manuals']

# %% [markdown]
# ### Adding a column for Average score of all in-company preparation exams

# %%
df['pre_exams_average'] = (df['hr_interview_score'] + df['x_ray_module_assessment_score'] +
                           df['etd_module_assessment_score']+ df['phy_module_assessment_score'] + 
                           df['dg_module_assessment_score'] + df['tsa_test_score']+ df['cbp_test_score'])/7
df.head()
# Out:
#    gender race_ethnicity level_of_education language_proficiency  \
# 0    male        group A        high school               fluent
# 1  female        group E       some college         intermediate
# 2    male        group A       some college               fluent
# 3  female        group E       some college               fluent
# 4    male        group E       some college               fluent
#
#   training_manuals  hr_interview_score  x_ray_module_assessment_score  \
# 0             none                  63                             74
# 1         provided                  83                             95
# 2             none                  46                             58
# 3         provided                  71                             83
# 4             none                  68                             80
#
#    etd_module_assessment_score  phy_module_assessment_score  \
# 0                           63                         69.0
# 1                           83                         89.0
# 2                           46                         52.0
# 3                           71                         77.0
# 4                           68                         74.0
#
#    dg_module_assessment_score  tsa_test_score  cbp_test_score  \
# 0                          66              63            62.0
# 1                          89              88            85.0
# 2                          47              43            43.0
# 3                          76              74            73.0
# 4                          72              72            65.0
#
#    Certification_exam_score  pre_exams_average
# 0                      63.0          65.714286
# 1                      75.0          87.428571
# 2                      53.0          47.857143
# 3                      66.0          75.000000
# 4                      68.0          71.285714

# %% [markdown]
# ####  convert the output numerical column (Certification_exam_score) into binary values
# - ( values greater than or equal to 60 are labeled as "1" for PASSED and values less than 60 are labeled as "0, for FAILED" )

# %%
df['Certification_exam_Outcome'] = df['Certification_exam_score'].apply(lambda x: 1 if x >= 60 else 0)

# %%
df.head(10)
# Out:
#    gender race_ethnicity level_of_education language_proficiency  \
# 0    male        group A        high school               fluent
# 1  female        group E       some college         intermediate
# 2    male        group A       some college               fluent
# 3  female        group E       some college               fluent
# 4    male        group E       some college               fluent
# 5    male        group B        high school               fluent
# 6  female        group E       some college         intermediate
# 7  female        group D   some high school               fluent
# 8    male        group C        high school               fluent
# 9    male        group C       some college               fluent
#
#   training_manuals  hr_interview_score  x_ray_module_assessment_score  \
# 0             none                  63                             74
# 1         provided                  83                             95
# 2             none                  46                             58
# 3         provided                  71                             83
# 4             none                  68                             80
# 5             none                  57                             68
# 6         provided                  50                             62
# 7             none                  59                             70
# 8             none                  68                             80
# 9         provided                  91                            100
#
#    etd_module_assessment_score  phy_module_assessment_score  \
# 0                           63                         69.0
# 1                           83                         89.0
# 2                           46                         52.0
# 3                           71                         77.0
# 4                           68                         74.0
# 5                           57                         63.0
# 6                           50                         56.0
# 7                           59                         65.0
# 8                           68                         74.0
# 9                           91                         97.0
#
#    dg_module_assessment_score  tsa_test_score  cbp_test_score  \
# 0                          66              63            62.0
# 1                          89              88            85.0
# 2                          47              43            43.0
# 3                          76              74            73.0
# 4                          72              72            65.0
# 5                          59              55            54.0
# 6                          56              55            54.0
# 7                          62              58            59.0
# 8                          71              67            67.0
# 9                          92              86            90.0
#
#    Certification_exam_score  pre_exams_average  Certification_exam_Outcome
# 0                      63.0          65.714286                           1
# 1                      75.0          87.428571                           1
# 2                      53.0          47.857143                           0
# 3                      66.0          75.000000                           1
# 4                      68.0          71.285714                           1
# 5                      62.0          59.000000                           1
# 6                      42.0          54.714286                           0
# 7                      59.0          61.714286                           0
# 8                      71.0          70.714286                           1
# 9                      98.0          92.428571                           1

# %%
# Interchange the order of columns  while keeping the rest as is
columns_to_move = ['pre_exams_average','Certification_exam_score', 'Certification_exam_Outcome']
new_columns_order = [col for col in df.columns if col not in columns_to_move] + columns_to_move

# Reorder the DataFrame's columns based on the new order
df = df[new_columns_order]
df.head()
# Out:
#    gender race_ethnicity level_of_education language_proficiency  \
# 0    male        group A        high school               fluent
# 1  female        group E       some college         intermediate
# 2    male        group A       some college               fluent
# 3  female        group E       some college               fluent
# 4    male        group E       some college               fluent
#
#   training_manuals  hr_interview_score  x_ray_module_assessment_score  \
# 0             none                  63                             74
# 1         provided                  83                             95
# 2             none                  46                             58
# 3         provided                  71                             83
# 4             none                  68                             80
#
#    etd_module_assessment_score  phy_module_assessment_score  \
# 0                           63                         69.0
# 1                           83                         89.0
# 2                           46                         52.0
# 3                           71                         77.0
# 4                           68                         74.0
#
#    dg_module_assessment_score  tsa_test_score  cbp_test_score  \
# 0                          66              63            62.0
# 1                          89              88            85.0
# 2                          47              43            43.0
# 3                          76              74            73.0
# 4                          72              72            65.0
#
#    pre_exams_average  Certification_exam_score  Certification_exam_Outcome
# 0          65.714286                      63.0                           1
# 1          87.428571                      75.0                           1
# 2          47.857143                      53.0                           0
# 3          75.000000                      66.0                           1
# 4          71.285714                      68.0                           1

# %%
# remove the decimal point
df['pre_exams_average'] = df['pre_exams_average'].astype(int)
df.head()
# Out:
#    gender race_ethnicity level_of_education language_proficiency  \
# 0    male        group A        high school               fluent
# 1  female        group E       some college         intermediate
# 2    male        group A       some college               fluent
# 3  female        group E       some college               fluent
# 4    male        group E       some college               fluent
#
#   training_manuals  hr_interview_score  x_ray_module_assessment_score  \
# 0             none                  63                             74
# 1         provided                  83                             95
# 2             none                  46                             58
# 3         provided                  71                             83
# 4             none                  68                             80
#
#    etd_module_assessment_score  phy_module_assessment_score  \
# 0                           63                         69.0
# 1                           83                         89.0
# 2                           46                         52.0
# 3                           71                         77.0
# 4                           68                         74.0
#
#    dg_module_assessment_score  tsa_test_score  cbp_test_score  \
# 0                          66              63            62.0
# 1                          89              88            85.0
# 2                          47              43            43.0
# 3                          76              74            73.0
# 4                          72              72            65.0
#
#    pre_exams_average  Certification_exam_score  Certification_exam_Outcome
# 0                 65                      63.0                           1
# 1                 87                      75.0                           1
# 2                 47                      53.0                           0
# 3                 75                      66.0                           1
# 4                 71                      68.0                           1

# %% [markdown]
# ## Check for Data Inbalance in target column

# %%
counts = df.groupby('Certification_exam_Outcome').size().reset_index(name='Count')

# Print the counts
print(counts)
# Out:
#    Certification_exam_Outcome  Count
# 0                           0    351
# 1                           1    766

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>INSIGHTS </b>&#9658
# Target column is not balanced

# %% [markdown]
# ### Cleaned df

# %%
selected_columns = ['gender','race_ethnicity','level_of_education',	'language_proficiency',	'training_manuals', 'Certification_exam_score','pre_exams_average',  'Certification_exam_Outcome']

df_final=df[selected_columns]

df_final.head()
# Out:
#    gender race_ethnicity level_of_education language_proficiency  \
# 0    male        group A        high school               fluent
# 1  female        group E       some college         intermediate
# 2    male        group A       some college               fluent
# 3  female        group E       some college               fluent
# 4    male        group E       some college               fluent
#
#   training_manuals  Certification_exam_score  pre_exams_average  \
# 0             none                      63.0                 65
# 1         provided                      75.0                 87
# 2             none                      53.0                 47
# 3         provided                      66.0                 75
# 4             none                      68.0                 71
#
#    Certification_exam_Outcome
# 0                           1
# 1                           1
# 2                           0
# 3                           1
# 4                           1

# %%
df_final.dtypes
# Out:
# gender                         object
# race_ethnicity                 object
# level_of_education             object
# language_proficiency           object
# training_manuals               object
# Certification_exam_score      float64
# pre_exams_average               int32
# Certification_exam_Outcome      int64
# dtype: object

# %%
# convert the target column Certification_exam_Outcome to obj type
df_final['Certification_exam_Outcome'] = df_final['Certification_exam_Outcome'].astype(str)

# %%
df_final.dtypes
# Out:
# gender                         object
# race_ethnicity                 object
# level_of_education             object
# language_proficiency           object
# training_manuals               object
# Certification_exam_score      float64
# pre_exams_average               int32
# Certification_exam_Outcome     object
# dtype: object

# %% [markdown]
# #### <font color=blue> i. Numerical Features Analysis </font>

# %%
df_final.describe(percentiles=[.8,.90,.95,.99]).T
# Out:
#                            count       mean        std   min   50%   80%  \
# Certification_exam_score  1117.0  66.687276  15.408065   0.0  67.0  80.0
# pre_exams_average         1117.0  71.414503  14.621359  13.0  72.0  84.0
#
#                            90%   95%     99%    max
# Certification_exam_score  87.0  91.0   99.84  100.0
# pre_exams_average         90.0  95.0  100.00  103.0

# %%
# define numerical & categorical columns
numeric_features = [feature for feature in df_final.columns if df_final[feature].dtype != 'O']
categorical_features = [feature for feature in df_final.columns if ((df[feature].dtypes=='O') & (feature not in ['Certification_exam_Outcome']))]

# print columns
print('There are {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nThere are {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# There are 2 numerical features : ['Certification_exam_score', 'pre_exams_average']
#
# There are 5 categorical features : ['gender', 'race_ethnicity', 'level_of_education', 'language_proficiency', 'training_manuals']

# %%
# univariate distribution of numerical features

plt.figure(figsize=(20,50))
plotnumber =1
for num_feature in numeric_features:
    skewness = df[num_feature].skew()
    ax = plt.subplot(12,3,plotnumber)
    sns.distplot(df[num_feature],hist_kws={"color": "blue"}, kde_kws={"color": "red"})
    plt.xlabel(num_feature)
    print(f"Skewness of column '{num_feature}': {skewness:.2f}")
    plotnumber+=1
    
plt.show()
# Out:
# Skewness of column 'Certification_exam_score': -0.25
# Skewness of column 'pre_exams_average': -0.27

# %% [markdown]
# The data distribution is left-skewed, and it may be influenced by outliers or values on the lower end of the scale

# %% [markdown]
# #### <font color=blue>ii. Categorical Features</font>

# %%
# count of each value in each cat column
cat_counts=[]
for cat_col in categorical_features:
    cat_counts = df_final[cat_col].value_counts()
    print(cat_counts)
    print('__________________________')
    cat_counts += 1
# Out:
# gender
# female    582
# male      520
# other      15
# Name: count, dtype: int64
# __________________________
# race_ethnicity
# group C    354
# group D    293
# group B    211
# group E    160
# group A     99
# Name: count, dtype: int64
# __________________________
# level_of_education
# high school           398
# some college          237
# associate's degree    231
# some high school      182
# bachelor's degree      49
# master's degree        20
# Name: count, dtype: int64
# __________________________
# language_proficiency
# fluent          724
# intermediate    373
# limitted         20
# Name: count, dtype: int64
# __________________________
# training_manuals
# none        717
# provided    400
# Name: count, dtype: int64
# __________________________

# %%
# Define Function to create lable percentages on top of count plot of each categorical feature
def percent_label(ax, spacing=0.5):
    p = 0
    for rect in ax.patches:
        p += rect.get_height()

    for rect in ax.patches:
        y_value = rect.get_height()
        x_value = rect.get_x() + rect.get_width() / 2
        space = spacing
        va = 'bottom'
        if y_value < 0:
            space *= -1
            va = 'top'
        label = "{:.2f}".format( y_value/p*100)
        ax.annotate(
            label,                      
            (x_value, y_value),         
            xytext=(0, space),          
            textcoords="offset points", 
            ha='center',                
            va=va)

# %%
# create the plot for the cat vars
for column in categorical_features:
    plt.figure(figsize=(12, 6))
    plt.xticks(rotation=40)
    print(column.title())
    ax = sns.countplot(x = df_final[column], palette=sns.color_palette('coolwarm', n_colors=2))
    percent_label(ax)
    plt.show()
# Out:
# Gender
# Race_Ethnicity
# Level_Of_Education
# Language_Proficiency
# Training_Manuals

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>INSIGHTS </b>&#9658
#     <ul>
#      <li> Gender: Highest Number (around 52%) of examinees are females and very few are Other </li>
#      <li> Race_Ethnicity: Around 32% of examinees are from Group C and on 9% from Group A. </li>
#      <li> Level_Of_Education: More number of examinees are Highschool grads and only few hold Bachelors or Masters degrees. </li>
#      <li> Language_Proficiency: Majority of the eaminees are fluent in Language </li>
#      <li> training_ manual:training manuals are not properly distributed to trainees </li>
#
# </ul>
# </div>

# %% [markdown]
# #### <font color=blue>iii. Target variable Analysis </font>

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
# Create a pie chart in the first column to show the percentage of target values
axs[0].pie(df_final['Certification_exam_Outcome'].value_counts(), labels=df_final['Certification_exam_Outcome'].value_counts().index, autopct='%1.1f%%', startangle=90)
axs[0].set_title('Percentage of PASS/FAIL Values')

# Create a count plot in the second column to show the count of each target value
plots=sns.countplot(data=df_final, x=df_final["Certification_exam_Outcome"], palette=sns.color_palette('coolwarm', n_colors=2))
for bar in plots.patches:
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')
axs[1].set_title('Count of PASS/FAIL Values')

# Display the plot
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>INSIGHTS </b>&#9658
#
#      Target variable Data is not balanced, but it is nice to have 50:50.
#
#
# </div>

# %% [markdown]
# #### <font color=blue>iv. Target variable vs num features Analysis </font>

# %%
# boxplots to show values of num features across Target var
fig=plt.figure(figsize=(15,10))
palette=sns.color_palette('coolwarm', n_colors=2)
for i in range(len(numeric_features)):
    column= numeric_features[i]
    sub=fig.add_subplot(3,3,i+1)
    sns.boxplot(x='Certification_exam_Outcome', y=column, data=df, palette=palette)

# %% [markdown]
# There are som outliers near the min value of thi column

# %% [markdown]
# ### Summary Statistics

# %%
summary_stats = df_final[['pre_exams_average']].describe()
print(summary_stats)
# Out:
#        pre_exams_average
# count        1117.000000
# mean           71.414503
# std            14.621359
# min            13.000000
# 25%            61.000000
# 50%            72.000000
# 75%            81.000000
# max           103.000000

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.histplot(df_final['pre_exams_average'], bins=20, kde=True)
plt.title('Distribution of pre_exams_average')


plt.subplot(1, 2, 2)
sns.histplot(df_final['Certification_exam_Outcome'], bins=20, kde=True)
plt.title('Distribution of Certification_exam_Outcome')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Data Visualization and insights

# %% [markdown]
# ### Categorical Variables:

# %%
plt.figure(figsize=(14, 10))

# Subplot 1: Gender Distribution
plt.subplot(2, 3, 1)
sns.countplot(data=df, x='gender')
plt.title('Gender Distribution')

# Subplot 2: Race/Ethnicity Distribution
plt.subplot(2, 3, 2)
sns.countplot(data=df, x='race_ethnicity')
plt.xticks(rotation=45)
plt.title('Race/Ethnicity Distribution')

# Subplot 3: Level of Education Distribution
plt.subplot(2, 3, 3)
sns.countplot(data=df, x='level_of_education')
plt.xticks(rotation=45)
plt.title('Level of Education Distribution')

# Subplot 4: Language Proficiency Distribution
plt.subplot(2, 3, 4)
sns.countplot(data=df, x='language_proficiency')
plt.title('Language Proficiency Distribution')

# Subplot 5: Training Manuals Distribution
plt.subplot(2, 3, 5)
sns.countplot(data=df, x='training_manuals')
plt.title('Training Manuals Distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Relationships and Correlations:

# %%
# relationships between numerical variables and the target variable
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.scatterplot(data=df_final, x='pre_exams_average', y='Certification_exam_Outcome')
plt.title('Scatter Plot: pre_exams_average vs. Certification_exam_outcome')


plt.tight_layout()
plt.show()

# %%
# # Repeat for Certification_exam_score on df (not df_final)
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.scatterplot(data=df, x='pre_exams_average', y='Certification_exam_score')
plt.title('Scatter Plot: pre_exams_average vs. Certification_exam_score')
plt.tight_layout()
plt.show()

# %% [markdown]
# There exists some linear relationship among them

# %%
correlation_coefficient = df_final['pre_exams_average'].corr(df['Certification_exam_score'])
print(f"Correlation Coefficient: {correlation_coefficient}")
# Out:
# Correlation Coefficient: 0.8881532795493179

# %%
summary_stats = df[['pre_exams_average', 'Certification_exam_score']].describe()
print(summary_stats)
# Out:
#        pre_exams_average  Certification_exam_score
# count        1117.000000               1117.000000
# mean           71.414503                 66.687276
# std            14.621359                 15.408065
# min            13.000000                  0.000000
# 25%            61.000000                 57.000000
# 50%            72.000000                 67.000000
# 75%            81.000000                 77.000000
# max           103.000000                100.000000

# %%
# pip install statsmodels
import statsmodels.api as sm

X = df['pre_exams_average']
X = sm.add_constant(X)  # Add a constant term (intercept)
y = df['Certification_exam_score']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     Certification_exam_score   R-squared:                       0.789
# Model:                                  OLS   Adj. R-squared:                  0.789
# Method:                       Least Squares   F-statistic:                     4165.
# Date:                      Mon, 18 Sep 2023   Prob (F-statistic):               0.00
# Time:                              01:16:14   Log-Likelihood:                -3770.8
# No. Observations:                      1117   AIC:                             7546.
# Df Residuals:                          1115   BIC:                             7556.
# Df Model:                                 1
# Covariance Type:                  nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.1525      1.057     -0.144      0.885      -2.227       1.922
# pre_exams_average     0.9359      0.015     64.535      0.000       0.907       0.964
# ==============================================================================
# Omnibus:                       22.063   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               12.658
# Skew:                           0.059   Prob(JB):                      0.00178
# Kurtosis:                       2.492   Cond. No.                         364.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### <font color=blue>vi. Target variable vs cat features Analysis </font>

# %%
# Create countplot showing count of each category by target value
i = 0
plt.figure(figsize=(20,20))
for cat_feature in categorical_features:
    i += 1
    plt.subplot(3, 3, i)
    plt.xticks(rotation=40)
    sns.countplot(x = df_final[cat_feature], data = df_final, hue = "Certification_exam_Outcome", palette=sns.color_palette('coolwarm', n_colors=2))
plt.show()

# %% [markdown]
# - Gender, training_manual--> no effect on final routcome
# - other variables are significant

# %% [markdown]
# ### Handling outliers

# %%
cols = ['Certification_exam_score']

for column in cols:

    Q1 = df_final[column].quantile(0.25)
    Q3 = df_final[column].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df_final[column] = np.where(df_final[column] < lower_bound, lower_bound, df_final[column])
    df_final[column] = np.where(df_final[column] > upper_bound, upper_bound, df_final[column])

# %% [markdown]
# ## Last cleaned data

# %%
selected_columns = ['gender','race_ethnicity','level_of_education',	'language_proficiency',	'training_manuals','pre_exams_average',  'Certification_exam_Outcome']

df_cleaned=df[selected_columns]

df_cleaned.head()
# Out:
#    gender race_ethnicity level_of_education language_proficiency  \
# 0    male        group A        high school               fluent
# 1  female        group E       some college         intermediate
# 2    male        group A       some college               fluent
# 3  female        group E       some college               fluent
# 4    male        group E       some college               fluent
#
#   training_manuals  pre_exams_average  Certification_exam_Outcome
# 0             none                 65                           1
# 1         provided                 87                           1
# 2             none                 47                           0
# 3         provided                 75                           1
# 4             none                 71                           1

# %% [markdown]
# ## Save Cleaned Data for Modeling

# %%
df_cleaned.to_csv('data/cleaned_data.csv', index=False)
